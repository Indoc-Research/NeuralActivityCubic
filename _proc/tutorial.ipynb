# %% [raw]
# ---
# output-file: tutorial.html
# title: Getting started
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %% [markdown]
# After you successfully completed the installation of neuralactivitycubic (NA³), open JupyterLab in your browser run the following commands in a Jupyter Notebook to open the graphical user interface (GUI) of NA³:

# %%
#|eval: false
import neuralactivitycubic as na3

na3.open_gui()

# %% [markdown]
# ![](./media/welcome_to_na3.png)

# %% [markdown]
# ## General Settings

# %% [markdown]
# lorem ipsum lorem ipsum lorem ipsum

# %% [markdown]
# ### ROI modes:

# %% [markdown]
# lorem ipsum lorem ipsum lorem ipsum

# %% [markdown]
# #### Grid (congruent squares):

# %% [markdown]
# lorem ipsum lorem ipsum lorem ipsum

# %% [markdown]
# #### Predefined ROIs:

# %% [markdown]
# lorem ipsum lorem ipsum lorem ipsum

# %% [markdown]
# ### Batch mode:

# %% [markdown]
# lorem ipsum lorem ipsum lorem ipsum

# %% [markdown]
# ### Focus areas:

# %% [markdown]
# lorem ipsum lorem ipsum lorem ipsum

# %% [markdown]
# ### Source data:

# %% [markdown]
# lorem ipsum lorem ipsum lorem ipsum

# %% [markdown]
# ## Analysis Settings:

# %% [markdown]
# lorem ipsum lorem ipsum lorem ipsum

# %% [markdown]
# ### Optional settings:

# %% [markdown]
# lorem ipsum lorem ipsum lorem ipsum

# %% [markdown]
# ### Result settings:

# %% [markdown]
# lorem ipsum lorem ipsum lorem ipsum

# %% [markdown]
# ## Generated Results:

# %% [markdown]
# lorem ipsum lorem ipsum lorem ipsum
